# %% [markdown]
# ### import dependencies

# %%
import json
import pandas as pd
import numpy as np
import re

# %%
# import json file
## with the [file_dir] variable, it can now be referenced as opposed to writing the filepath
file_dir = 'C:/Users/shannon/Desktop/Bootcamp/8-ETL/Movies-ETL'

# %% [markdown]
# # create a list from the json file
# use `with` to open the Wikipedia JSON file to be read into the variable `file`,
# and use `json.load()` to save the data to a new variable.

# %%
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
#### show number of records
len(wiki_movies_raw)
# Out:
# 7311

# %% [markdown]
# # check the data
# ## specific chunks of the list
# use index slices rather than `head()` `tail()` method (Dataframes)

# %%
# First 5 records
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
# ...

# %%
# Last 5 records
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
# ...

# %%
# Some records in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %% [markdown]
# # 8.2.2 Extract Kaggle Data files
# its already a flat-file formats, so pull them into Pandas DataFrames directly.

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 3816318    39755      597     4.0   849282761
# 14161804  147128     1635     4.0  1039851833
# 17521740  181815     1995     5.0  1206544556
# 18438541  191338    42002     4.0  1150157570
# 25889628  269416      454     4.0   837539163

# %%
kaggle_metadata.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 14444  False                   NaN      0
# 3005   False                   NaN      0
# 851    False                   NaN      0
# 20806  False                   NaN      0
# 15804  False                   NaN      0
#
#                                                   genres homepage      id  \
# 14444                      [{'id': 18, 'name': 'Drama'}]      NaN   71329
# 3005   [{'id': 28, 'name': 'Action'}, {'id': 37, 'nam...      NaN    1718
# 851    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  110513
# 20806  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...      NaN   15257
# 15804  [{'id': 99, 'name': 'Documentary'}, {'id': 18,...      NaN   85692
#
#          imdb_id original_language      original_title  \
# 14444  tt0094349                bm              Yeelen
# 3005   tt0033021                en      Santa Fe Trail
# 851    tt0116418                en          Girls Town
# ...

# %% [markdown]
# # 8.3.3 Inspect wiki data
# since wiki raw is a list of dict all that is needed is the df function

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)

# %%
wiki_movies_df.head(5)
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %% [markdown]
# how to see all of the columns in the df - use the columns function and convert to a list

# %%
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...

# %% [markdown]
# ## use list comprehension to filter data
# where the resulting list will only have elements where the filter expression evaluates to True.
#
# EX: [expression `for` element `in` source_list `if` filter_expression]

# %%
# filter list to only show titles that have a dir, or dir by and imdb link 
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie]
# show row count
len(wiki_movies)
# Out:
# 7080

# %%
# make a df from filtered list
wiki_movies_dir_df = pd.DataFrame(wiki_movies)

# %%
#show first five rows
wiki_movies_dir_df.head(5)
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# ...

# %% [markdown]
# filter df on on more condition - episodes

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]

# show row count
len(wiki_movies)
# Out:
# 7076

# %% [markdown]
# # 8.3.5 create a function to clean the data
# 4 parts: name; param; code; return value

# %% [markdown]
#  since movies are a dict, to make nondestructive edits copy  with constructor `dict()`
#  constructors  = function that initializes a new object

# %% [markdown]
# 4:1 -name- `def clean_movie`
#
# 4:2 -local param- `movie = dict()`
#
# 4:3 -code- `(movie)`
#
# 4:4 -return value- `return movie`

# %%
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    return movie

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url    year  \
# 7060  https://en.wikipedia.org/wiki/The_Insult_(film)  2018.0
# 7293   https://en.wikipedia.org/wiki/Capernaum_(film)  2018.0
#
#                                   imdb_link       title    Directed by  \
# 7060  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7293  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 7060  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7293                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 7060                                                NaN
# 7293  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 7060                                                NaN      NaN
# 7293  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
# ...

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]['url']
# Out:
# 7060    https://en.wikipedia.org/wiki/The_Insult_(film)
# 7293     https://en.wikipedia.org/wiki/Capernaum_(film)
# Name: url, dtype: object

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Actor control',
#  'Adaptation by',
#  'Alias',
#  'Alma mater',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Area',
#  'Area served',
#  'Artist(s)',
#  'Attraction type',
#  'Audio format',
#  'Author',
#  'Based on',
#  'Biographical data',
#  'Bopomofo',
#  'Born',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cantonese',
#  'Characters',
#  'Children',
#  'Chinese',
#  'Cinematography',
#  'Closing date',
#  'Color process',
#  'Comics',
#  'Composer(s)',
#  'Coordinates',
#  'Country',
#  'Country of origin',
#  'Cover artist',
#  'Created by',
#  'Date premiered',
#  'Designer(s)',
#  'Developed by',
#  'Developer(s)',
#  'Dewey Decimal',
#  'Died',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Divisions',
#  'Duration',
#  'Edited by',
#  'Editor(s)',
#  'Ending theme',
#  'Engine',
#  'Engine(s)',
#  'Executive producer(s)',
#  'Family',
#  'Fate',
#  'Film(s)',
#  'Followed by',
#  'Format(s)',
#  'Formerly',
#  'Founded',
# ...

# %%
## Step 1: Make an empty dict to hold all of the alternative titles.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}

## Step 2: Loop through a list of all alternative title keys. - combine into one column.
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:

## Step 2a: Check if the current key exists in the movie object.     
        if key in movie:

## Step 2b: If so, remove the key-value pair and add to the alternative titles dictionary.
            alt_titles[key] = movie[key]
            movie.pop(key)

## Step 3: After looping through every key, add the alternative titles dict to the movie object.
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    return movie

# %% [markdown]
# #### use list comprehension to make a list of cleaned movies

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %% [markdown]
# #### connect/point `wiki_movie_df` to clean_movies dict

# %%
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'No. of episodes',
#  'Opening theme',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
# ...

# %% [markdown]
# # 8.3.6 Clean and Consolidate
#
# use `pop()` method to change the name of a dict key
#
# notation: 1)name functions as verbs for easier understanding 2) spell it out.

# %%
# section is a copy of the first def
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}

    # combine alternate titles into one list
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

# new section consolodates more columns
    # merge more column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Directed by', 'Director')
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')

    return movie

# %% [markdown]
# #### use `list comprehension` to clean wiki_movies and recreate wiki_movies_df

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Narrated by',
#  'No. of episodes',
#  'Opening theme',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %% [markdown]
# # 8.3.7 Clean up the Rows
# #### extract imdb_id from imdb_link
# use regex (string of char that define a pattern)  `str.extract()`
#
# `(r'(tt\d{7})')` - look for a group of characters that start with "tt" and has seven digits
#
# 1. outside() - group the phrase
# 2. `tt` - match two lowercase t's
# 3. `\d` - match a numberical digit
# 4. `{7}` - has seven numbers
# 5. `r` - tells python regex is a string of txt (not a python special char)

# %%
# create a new column for the id and extract from url
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
# Out:
# 7080

# %% [markdown]
# #### drop dups `drop_duplocates` method, limit to only the id `subset = imdb_id`, on selected df `inplace=true`

# %%
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
# Out:
# 7037

# %%
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# ...

# %% [markdown]
# #### remove mostly null columns

# %%
# get count of nulls values for each column
[[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Based on', 4855],
#  ['Starring', 185],
#  ['Narrated by', 6755],
#  ['Cinematography', 693],
#  ['Release date', 32],
#  ['Running time', 139],
#  ['Country', 236],
#  ['Language', 248],
#  ['Budget', 2298],
#  ['Box office', 1552],
#  ['Director', 0],
#  ['Distributor', 360],
#  ['Editor(s)', 548],
#  ['Composer(s)', 519],
#  ['Producer(s)', 203],
#  ['Production company(s)', 1678],
#  ['Writer(s)', 201],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6937],
#  ['Production location(s)', 6987],
#  ['Picture format', 6969],
#  ['Audio format', 6973],
#  ['Voices of', 7035],
#  ['Followed by', 7028],
#  ['Created by', 7026],
#  ['Opening theme', 7036],
#  ['No. of episodes', 7033],
#  ['alt_titles', 7015],
#  ['Preceded by', 7027],
#  ['Suggested by', 7036],
#  ['Recorded', 7035],
#  ['Venue', 7036],
#  ['Label', 7035],
# ...

# %% [markdown]
# #### make a list that has less than 90% (0.9) null values to trim down the dataset

# %%
# adjust the prevous list comprehension with an IF/THEN
[column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Based on',
#  'Starring',
#  'Cinematography',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Composer(s)',
#  'Producer(s)',
#  'Production company(s)',
#  'Writer(s)',
#  'imdb_id']

# %% [markdown]
# #### select those columns from the panda df

# %%
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

# %% [markdown]
# # 8.3.8 Convert and Parse the Data
#
# check data types

# %%
# identify the existing datatypes
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
# drop rows with missing values
box_office = wiki_movies_df['Box office'].dropna()

# %%
# show row count after drop
print(len(box_office))
# Out:
# 5485

# %% [markdown]
# define a funtion that shows which cells are not strings (long hand)

# %%
def is_not_a_string(x):
    return type(x) != str
box_office[box_office.map(is_not_a_string)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 75                    [$6,488,144, (US), [1]]
# 127                [US$1,531,489, (domestic)]
# 131                          [US$, 4,803,039]
#                         ...
# 6984               [$99.6, million, [4], [5]]
# 6998                   [$365.6, million, [1]]
# 6999                         [$53.8, million]
# 7019                     [$435, million, [7]]
# 7052                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %% [markdown]
# ALT Method: instead use lambda function with `.map` call (short hand)
#
# 1. `box_office[box_office.map()]` - map call
# 2. `(lambda x: type(x) != str)` - lambda function

# %%
box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 75                    [$6,488,144, (US), [1]]
# 127                [US$1,531,489, (domestic)]
# 131                          [US$, 4,803,039]
#                         ...
# 6984               [$99.6, million, [4], [5]]
# 6998                   [$365.6, million, [1]]
# 6999                         [$53.8, million]
# 7019                     [$435, million, [7]]
# 7052                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# concatenate list items (multiple data points in one field- commas)
box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)

# %% [markdown]
# # 8.3.10 Parse the Box Office data
# box office data
#
# 1. `\$` A (literal)dollar sign
# 2. `\d+` An arbitrary (but non-zero) number of digits
# 3. `\.?` An optional decimal point
# 4. `\d*` An arbitrary (but possibly zero) number of more digits
# 5. `\s*` A space (maybe more than one)
# 6. `[mb]illion` The word "million" or "billion"

# %%
# create a variable 'form_one' ($###.# million)
form_one = r'\$\d+\.?\d*\s*[mb]illion'

# %%
# count how many rows match the variable
box_office.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
# Out:
# 3896

# %%
# create a second variable 'form_two' ($###,###,###)
form_two = r'\$\d{1,3}(?:,\d{3})+'
box_office.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
# Out:
# 1544

# %%
# create a third variable to show all the others not already defined
# first create two boolean series to match on (Y/N)
matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE, na=False)

# %%
# this will throw an error!
## PYTHON EX: box_office[(not matches_form_one) and (not matches_form_two)]

# use Panda logical operators instead
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34                         US$ 4,212,828
# 80                              $335.000
# 111                   $4.35-4.37 million
# 131                        US$ 4,803,039
# 602                           $5000 (US)
# 733                         $ 11,146,270
# 959                             $ 50,004
# 1072                          35,254,617
# 1150    $ 407,618 (U.S.) (sub-total) [1]
# 1449                        $ 11,829,959
# 1483                          £3 million
# 1614                            $520.000
# 1868                        ¥1.1 billion
# 2036                                 N/A
# 2095                                $309
# 2134               US$ 171.8 million [9]
# 2261                   US$ 3,395,581 [1]
# 2267            $ 1,223,034 ( domestic )
# 2351                            $282.175
# 2642            $ 104,883 (US sub-total)
# 2669         926,423 admissions (France)
# 2701      $ 1.7 million (US) (sub-total)
# 2827                            $414.000
# ...

# %% [markdown]
# #### Fix pattern matches to capture more values
#
# 1. `[mb]illi?on` mispellings
# 2. `\s` odd spaces btw the dollar sign and number (both forms)
# 3. `[,\.]` period instead of comma (form 2)
# 4. values as ranges - use concantonated list

# %%
form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'

# %%
# fix values as ranages
box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %% [markdown]
# #### extract and convert only the parts that match
#
# use an `f-string` with a regex to capture both forms

# %%
box_office.str.extract(f'({form_one}|{form_two})')
# Out:
#                   0
# 0     $21.4 million
# 1      $2.7 million
# 2       $57,718,089
# 3        $7,331,647
# 4        $6,939,946
# ...             ...
# 7074  $19.4 million
# 7075  $41.9 million
# 7076  $76.1 million
# 7077  $38.4 million
# 7078   $5.5 million
#
# [5485 rows x 1 columns]

# %% [markdown]
# #### convert the values to number with a function
#
# 1. use `re.match(pattern, string)` to see if our string matches a pattern.
# 2. use `re.sub(pattern, replacement_string, string)` to remove dollar signs, spaces, commas, and letters, if necessary.
# 3. convert all the strings to floats, multiply by the right amount, and return the value.

# %%
def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan

    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a million
        value = float(s) * 10**6

        # return value
        return value

    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a billion
        value = float(s) * 10**9

        # return value
        return value

    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):

        # remove dollar sign and commas
        s = re.sub('\$|,','', s)

        # convert to float
        value = float(s)

        # return value
        return value

    # otherwise, return NaN
    else:
        return np.nan

# %%
# create new box office column
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
wiki_movies_df['box_office']
# Out:
# 0       21400000.0
# 1        2700000.0
# 2       57718089.0
# 3        7331647.0
# 4        6939946.0
#            ...
# 7075    41900000.0
# 7076    76100000.0
# 7077    38400000.0
# 7078     5500000.0
# 7079           NaN
# Name: box_office, Length: 7037, dtype: float64

# %%
# drop old box office column
wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %% [markdown]
# # 8.3.11 Parse the Budget Data

# %%
# create a new variable
budget = wiki_movies_df['Budget'].dropna()

# comvert amy lists to strings
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# clean up the formatting -spaces, hyphens etc
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
# parse data, find the entries that don't match the forms
matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)
budget[~matches_form_one & ~matches_form_two]
# Out:
# 137                         Unknown
# 205     60 million Norwegian Kroner
# 479                         Unknown
# 975             $34 [3] [4] million
# 1129               $120 [4] million
# 1229                        Unknown
# 1281                            HBO
# 1377                     £6,000,000
# 1400                     13 million
# 1483                   £2.8 million
# 1737                   CAD2,000,000
# 1916     PHP 85 million (estimated)
# 1951                    102,888,900
# 1956                   3,500,000 DM
# 1976                     ₤2,300,874
# 2285                     $14 milion
# 2455                     ₤6,350,000
# 3148                   € 40 million
# 3364               $150 [6] million
# 3422                        $218.32
# 3806                   £4.2 million
# 3910                            N/A
# 3963                    760,000 USD
# 4474                       19 crore
# 4645                    £17 million
# 5038              $$200 [4] million
# ...

# %%
# remove the citation refs ([4])
budget = budget.str.replace(r'\[\d+\]\s*', '')
budget[~matches_form_one & ~matches_form_two]
# Out:
# C:\Users\shannon\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
# 137                         Unknown
# 205     60 million Norwegian Kroner
# 479                         Unknown
# 975                     $34 million
# 1129                   $120 million
# 1229                        Unknown
# 1281                            HBO
# 1377                     £6,000,000
# 1400                     13 million
# 1483                   £2.8 million
# 1737                   CAD2,000,000
# 1916     PHP 85 million (estimated)
# 1951                    102,888,900
# 1956                   3,500,000 DM
# 1976                     ₤2,300,874
# 2285                     $14 milion
# 2455                     ₤6,350,000
# 3148                   € 40 million
# 3364                   $150 million
# 3422                        $218.32
# 3806                   £4.2 million
# ...

# %%
# parse the data into a new column
wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
wiki_movies_df['budget']
# Out:
# 0       20000000.0
# 1        6000000.0
# 2       35000000.0
# 3       12000000.0
# 4       25000000.0
#            ...
# 7075    42000000.0
# 7076    60000000.0
# 7077    20000000.0
# 7078     9000000.0
# 7079           NaN
# Name: budget, Length: 7037, dtype: float64

# %%
# drop the old Budget column (case sensitive)
wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %% [markdown]
# # Parse Release Date
# 1. fix `month, dd, yyyy`
# 2. fix `yyyy-mm-dd` and `yyyy/mm/dd`
# 3. fix `month yyyy`
# 4. fix `yyyy`

# %%
# create the variable and convert to string at the same time
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
# fix the data with regex
date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}'
date_form_two = r'\d{4}.[01]\d.[0123]\d'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'

# %%
# extract the dates
release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)
# Out:
#                       0
# 0         July 11, 1990
# 1          May 17, 1990
# 2       August 10, 1990
# 3     December 25, 1990
# 4     December 19, 1990
# ...                 ...
# 7075  December 25, 2018
# 7076  December 11, 2018
# 7077   November 8, 2018
# 7078    August 31, 2018
# 7079      December 2018
#
# [7005 rows x 1 columns]

# %%
 # parse the date into a new column
wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)
wiki_movies_df['release_date']
# Out:
# 0      1990-07-11
# 1      1990-05-17
# 2      1990-08-10
# 3      1990-12-25
# 4      1990-12-19
#           ...
# 7075   2018-12-25
# 7076   2018-12-11
# 7077   2018-11-08
# 7078   2018-08-31
# 7079   2018-12-01
# Name: release_date, Length: 7037, dtype: datetime64[ns]

# %% [markdown]
# # Parse Running Time

# %%
# create a variable and covert to list
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
# count how many rows look like '### minutes'
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6531

# %%
# show rows that don't match the pattern
running_time[running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False) != True]
# Out:
# 9                                                 102 min
# 26                                                 93 min
# 28                                                32 min.
# 34                                                101 min
# 35                                                 97 min
#                               ...
# 6504       114 minutes [1] 120 minutes (extended edition)
# 6647                                             104 mins
# 6713    90 minutes (theatrical) [1] 91 minutes (unrate...
# 7061    108 minutes (Original cut) 98 minutes (UK cut)...
# 7079                Variable; 90 minutes for default path
# Name: Running time, Length: 367, dtype: object

# %%
# modify the regex to include more values - accept different spellings
running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6881

# %%
running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False) != True]
# Out:
# 670                     UK:84 min (DVD version) US:86 min
# 729                         78-102 min (depending on cut)
# 842                       Varies (79 [3] –84 [1] minutes)
# 1350                                              25 : 03
# 1446    United States: 77 minutes Argentina: 94 minute...
# 1502                                            1hr 35min
# 1554                                               varies
# 1777                    Netherlands:96 min, Canada:95 min
# 1780                                       approx. 14 min
# 2277                                           1 h 43 min
# 2997                                               1h 48m
# 3929                                              4 hours
# 4429    US domestic version: 86 minutes Original versi...
# 4971    Theatrical cut: 97 minutes Unrated cut: 107 mi...
# 5428                    115 [1] /123 [2] /128 [3] minutes
# 5451                                    1 hour 32 minutes
# ...

# %%
# extract only the digits
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')
running_time_extract
# Out:
#         0    1    2
# 0     NaN  NaN  102
# 1     NaN  NaN  114
# 2     NaN  NaN  113
# 3     NaN  NaN  106
# 4     NaN  NaN   95
# ...   ...  ...  ...
# 7075  NaN  NaN   90
# 7076  NaN  NaN  132
# 7077  NaN  NaN  120
# 7078  NaN  NaN  123
# 7079  NaN  NaN   90
#
# [6898 rows x 3 columns]

# %% [markdown]
# 1. use the `to_numeric()` method and set the errors argument to `'coerce'`.
# 2. coercing the errors will turn the empty strings into Not a Number (NaN),
# 3. then we can use `fillna()` to change all the NaNs to zeros.

# %%
running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)
running_time_extract
# Out:
#         0    1      2
# 0     0.0  0.0  102.0
# 1     0.0  0.0  114.0
# 2     0.0  0.0  113.0
# 3     0.0  0.0  106.0
# 4     0.0  0.0   95.0
# ...   ...  ...    ...
# 7075  0.0  0.0   90.0
# 7076  0.0  0.0  132.0
# 7077  0.0  0.0  120.0
# 7078  0.0  0.0  123.0
# 7079  0.0  0.0   90.0
#
# [6898 rows x 3 columns]

# %%
# create new col by convert the hour and min groups to min
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)

# %%
# drop  old running time column
wiki_movies_df.drop('Running time', axis=1, inplace=True)

# %% [markdown]
# # 8.3.12 Kaggle Data
